# %% [markdown]
# # Correlación y covarianza

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (20,15) 

pd.options.display.max_columns=None
pd.options.display.float_format = '{:.2f}'.format 
np.set_printoptions(suppress=True)

# %%
df = pd.read_csv('../Datos/EDA_vinos.csv', index_col= 0)
df.head()
# Out:
#      id  year_birth   education marital_status   income  kidhome  teenhome  \
# 0  5524        1957  Graduation         Single  58138.0        0         0
# 1  2174        1954  Graduation         Single  46344.0        1         1
# 2  4141        1965  Graduation       Together  71613.0        0         0
# 3  6182        1984  Graduation       Together  26646.0        1         0
# 4  5324        1981         PhD        Married  58293.0        1         0
#
#   dt_customer  recency  mntwines  mntfruits  mntmeatproducts  mntfishproducts  \
# 0  04-09-2012       58       635         88              546              172
# 1  08-03-2014       38        11          1                6                2
# 2  21-08-2013       26       426         49              127              111
# 3  10-02-2014       26        11          4               20               10
# 4  19-01-2014       94       173         43              118               46
#
#    mntsweetproducts  mntgoldprods  numdealspurchases  numwebpurchases  \
# 0                88            88                  3                8
# 1                 1             6                  2                1
# 2                21            42                  1                8
# 3                 3             5                  2                2
# 4                27            15                  5                5
#
#    numcatalogpurchases  numstorepurchases  numwebvisitsmonth  \
# 0                   10                  4                  7
# 1                    1                  2                  5
# 2                    2                 10                  4
# 3                    0                  4                  6
# 4                    3                  6                  5
#
#    mnt_total_sin_vino
# 0                 982
# 1                  16
# 2                 350
# 3                  42
# 4                 249

# %% [markdown]
# `En este ejercicio de pair programming seguiréis usando el dataset que seleccionasteis ayer.`
# 1. Pregunta teórica: ¿Qué diferencia existe entre la covarianza y la correlación?

# %% [markdown]
# >- La `covarianza` indica si ambas variables varían en la misma dirección
# >- **covarianza positiva**: si aumenta el valor de una variable aumenta el variable de la otra
# >- **covarianza negativa**: cuando aumenta el valor de una de las variables, disminuye el de la otra.
# >- El valor de la covarianza no es importante, solo el signo (si es positivo o negativo)

# %% [markdown]
# >- La `correlación` varía entre -1 y 1. Dos variables están asociadas o correlacionadas cuando una variable nos da información acerca de la otra. La correlación indica la dirección (positiva o negativa) y la "fuerza" de esa relación.
# >
# >   - Si el valor de la correlación es 0 significa que no hay relación entre las variables.
# >
# >    - Si el valor es positivo significa que cuando aumenta el valor de una variable aumenta el de la otra.
# >
# >    - Si el valor es negativo significa que cuando disminuye el valor de una variable disminuye el de la otra.

# %% [markdown]
# 2. Calculad la covarianza y la correlación de nuestro dataset. No nos vale solo con que la calculéis, debéis hacer una interpretación de los resultados obtenidos. Calculad solo la correlación de Pearson.

# %%
# Calculamos la covarianza
df.cov()
# Out:
#                              id  year_birth  kidhome  teenhome  recency  \
# id                  10540815.43        1.07     4.20     -4.56 -4374.72
# year_birth                 1.07      143.62     1.49     -2.30    -6.90
# kidhome                    4.20        1.49     0.29     -0.01     0.14
# teenhome                  -4.56       -2.30    -0.01      0.30     0.26
# recency                -4374.72       -6.90     0.14      0.26   838.82
# mntwines              -25001.81     -636.42   -89.94      0.89   156.60
# mntfruits                594.01       -8.54    -7.98     -3.83    -4.96
# mntmeatproducts        -3251.69      -83.51   -53.12    -32.10   150.72
# mntfishproducts        -4340.92      -27.25   -11.40     -6.07     1.71
# mntsweetproducts       -1024.15       -8.97    -8.24     -3.65    27.10
# mntgoldprods           -2275.97      -38.65    -9.82     -0.62    25.22
# numdealspurchases       -233.15       -1.41     0.23      0.41    -0.06
# numwebpurchases         -170.72       -4.83    -0.54      0.24    -0.86
# numcatalogpurchases      -32.65       -4.25    -0.79     -0.18     2.13
# numstorepurchases       -157.55       -5.00    -0.87      0.09     0.08
# numwebvisitsmonth        -58.66        3.52     0.59      0.18    -1.51
# mnt_total_sin_vino    -10298.72     -166.92   -90.56    -46.27   199.80
#
#                      mntwines  mntfruits  mntmeatproducts  mntfishproducts  \
# id                  -25001.81     594.01         -3251.69         -4340.92
# year_birth            -636.42      -8.54           -83.51           -27.25
# kidhome                -89.94      -7.98           -53.12           -11.40
# teenhome                 0.89      -3.83           -32.10            -6.07
# recency                156.60      -4.96           150.72             1.71
# mntwines            113297.80    5216.31         42748.70          7350.64
# mntfruits             5216.31    1581.93          4875.71          1292.38
# mntmeatproducts      42748.70    4875.71         50947.43          7008.74
# mntfishproducts       7350.64    1292.38          7008.74          2984.33
# mntsweetproducts      5371.51     931.21          4881.01          1307.67
# mntgoldprods          6804.55     815.42          4128.41          1205.13
# numdealspurchases        7.12     -10.15           -53.39           -14.71
# numwebpurchases        507.18      32.79           184.25            44.58
# numcatalogpurchases    625.00      56.73           477.57            85.35
# numstorepurchases      702.63      59.71           351.97            81.67
# numwebvisitsmonth     -261.91     -40.38          -295.48           -59.12
# mnt_total_sin_vino   67491.72    9496.64         71841.30         13798.25
#
#                      mntsweetproducts  mntgoldprods  numdealspurchases  \
# id                           -1024.15      -2275.97            -233.15
# year_birth                      -8.97        -38.65              -1.41
# kidhome                         -8.24         -9.82               0.23
# teenhome                        -3.65         -0.62               0.41
# recency                         27.10         25.22              -0.06
# mntwines                      5371.51       6804.55               7.12
# mntfruits                      931.21        815.42             -10.15
# mntmeatproducts               4881.01       4128.41             -53.39
# mntfishproducts               1307.67       1205.13             -14.71
# mntsweetproducts              1704.08        796.20              -9.58
# mntgoldprods                   796.20       2721.44               4.95
# numdealspurchases               -9.58          4.95               3.73
# numwebpurchases                 39.98         61.15               1.26
# numcatalogpurchases             59.24         66.74              -0.05
# numstorepurchases               60.22         64.73               0.43
# numwebvisitsmonth              -42.40        -31.74               1.63
# mnt_total_sin_vino            9620.17       9666.60             -82.89
#
#                      numwebpurchases  numcatalogpurchases  numstorepurchases  \
# id                           -170.72               -32.65            -157.55
# year_birth                     -4.83                -4.25              -5.00
# kidhome                        -0.54                -0.79              -0.87
# teenhome                        0.24                -0.18               0.09
# recency                        -0.86                 2.13               0.08
# mntwines                      507.18               625.00             702.63
# mntfruits                      32.79                56.73              59.71
# mntmeatproducts               184.25               477.57             351.97
# mntfishproducts                44.58                85.35              81.67
# mntsweetproducts               39.98                59.24              60.22
# mntgoldprods                   61.15                66.74              64.73
# numdealspurchases               1.26                -0.05               0.43
# numwebpurchases                 7.72                 3.07               4.54
# numcatalogpurchases             3.07                 8.54               4.93
# numstorepurchases               4.54                 4.93              10.57
# numwebvisitsmonth              -0.38                -3.69              -3.38
# mnt_total_sin_vino            362.75               745.63             618.30
#
#                      numwebvisitsmonth  mnt_total_sin_vino
# id                              -58.66           -10298.72
# year_birth                        3.52             -166.92
# kidhome                           0.59              -90.56
# teenhome                          0.18              -46.27
# recency                          -1.51              199.80
# mntwines                       -261.91            67491.72
# mntfruits                       -40.38             9496.64
# mntmeatproducts                -295.48            71841.30
# mntfishproducts                 -59.12            13798.25
# mntsweetproducts                -42.40             9620.17
# mntgoldprods                    -31.74             9666.60
# numdealspurchases                 1.63              -82.89
# numwebpurchases                  -0.38              362.75
# numcatalogpurchases              -3.69              745.63
# numstorepurchases                -3.38              618.30
# numwebvisitsmonth                 5.89             -469.13
# mnt_total_sin_vino             -469.13           114422.96

# %% [markdown]
# > Por ejemplo:
# >
# >- En el caso de las cantidades gastadas por producto`mnt...`, la covarianza con `income` es positiva, lo que indica que a mayores ingresos, más consumo, como es de esperar.
# >
# >O algo curioso:
# >
# >- La covarianza ente `income` y `kidhome` es negativa, osea, cuantos más hijos pequeños menos ingresos. Mientras que `income` con `teenhome` es positiva, cuando los hijos crecen aumentan los ingresos del hogar.
# >- La covarianza entre `recency` y `mntwines`es positiva, a mayor tiempo transcurrido entre compras, mayor el gasto en todos los productos menos en frutas, `mntfruits`, que muestra una covarianza negativa.
# >- La covarianza entre `mntwines` y `kidhome` es negativa, cuantos más hijos pequeños, menos vino se consume. Mientas que con `teenhome` la covarianza es positiva, cuanto mayores los hijos más vino se consume.

# %%
# Calculamos la matriz de correlación para todas nuestras variables, utilizamos el método por defecto, 'pearson'
df.corr(method='pearson')
# Out:
#                        id  year_birth  kidhome  teenhome  recency  mntwines  \
# id                   1.00        0.00     0.00     -0.00    -0.05     -0.02
# year_birth           0.00        1.00     0.23     -0.35    -0.02     -0.16
# kidhome              0.00        0.23     1.00     -0.04     0.01     -0.50
# teenhome            -0.00       -0.35    -0.04      1.00     0.02      0.00
# recency             -0.05       -0.02     0.01      0.02     1.00      0.02
# mntwines            -0.02       -0.16    -0.50      0.00     0.02      1.00
# mntfruits            0.00       -0.02    -0.37     -0.18    -0.00      0.39
# mntmeatproducts     -0.00       -0.03    -0.44     -0.26     0.02      0.56
# mntfishproducts     -0.02       -0.04    -0.39     -0.20     0.00      0.40
# mntsweetproducts    -0.01       -0.02    -0.37     -0.16     0.02      0.39
# mntgoldprods        -0.01       -0.06    -0.35     -0.02     0.02      0.39
# numdealspurchases   -0.04       -0.06     0.22      0.39    -0.00      0.01
# numwebpurchases     -0.02       -0.15    -0.36      0.16    -0.01      0.54
# numcatalogpurchases -0.00       -0.12    -0.50     -0.11     0.03      0.64
# numstorepurchases   -0.01       -0.13    -0.50      0.05     0.00      0.64
# numwebvisitsmonth   -0.01        0.12     0.45      0.13    -0.02     -0.32
# mnt_total_sin_vino  -0.01       -0.04    -0.50     -0.25     0.02      0.59
#
#                      mntfruits  mntmeatproducts  mntfishproducts  \
# id                        0.00            -0.00            -0.02
# year_birth               -0.02            -0.03            -0.04
# kidhome                  -0.37            -0.44            -0.39
# teenhome                 -0.18            -0.26            -0.20
# recency                  -0.00             0.02             0.00
# mntwines                  0.39             0.56             0.40
# mntfruits                 1.00             0.54             0.59
# mntmeatproducts           0.54             1.00             0.57
# mntfishproducts           0.59             0.57             1.00
# mntsweetproducts          0.57             0.52             0.58
# mntgoldprods              0.39             0.35             0.42
# numdealspurchases        -0.13            -0.12            -0.14
# numwebpurchases           0.30             0.29             0.29
# numcatalogpurchases       0.49             0.72             0.53
# numstorepurchases         0.46             0.48             0.46
# numwebvisitsmonth        -0.42            -0.54            -0.45
# mnt_total_sin_vino        0.71             0.94             0.75
#
#                      mntsweetproducts  mntgoldprods  numdealspurchases  \
# id                              -0.01         -0.01              -0.04
# year_birth                      -0.02         -0.06              -0.06
# kidhome                         -0.37         -0.35               0.22
# teenhome                        -0.16         -0.02               0.39
# recency                          0.02          0.02              -0.00
# mntwines                         0.39          0.39               0.01
# mntfruits                        0.57          0.39              -0.13
# mntmeatproducts                  0.52          0.35              -0.12
# mntfishproducts                  0.58          0.42              -0.14
# mntsweetproducts                 1.00          0.37              -0.12
# mntgoldprods                     0.37          1.00               0.05
# numdealspurchases               -0.12          0.05               1.00
# numwebpurchases                  0.35          0.42               0.23
# numcatalogpurchases              0.49          0.44              -0.01
# numstorepurchases                0.45          0.38               0.07
# numwebvisitsmonth               -0.42         -0.25               0.35
# mnt_total_sin_vino               0.69          0.55              -0.13
#
#                      numwebpurchases  numcatalogpurchases  numstorepurchases  \
# id                             -0.02                -0.00              -0.01
# year_birth                     -0.15                -0.12              -0.13
# kidhome                        -0.36                -0.50              -0.50
# teenhome                        0.16                -0.11               0.05
# recency                        -0.01                 0.03               0.00
# mntwines                        0.54                 0.64               0.64
# mntfruits                       0.30                 0.49               0.46
# mntmeatproducts                 0.29                 0.72               0.48
# mntfishproducts                 0.29                 0.53               0.46
# mntsweetproducts                0.35                 0.49               0.45
# mntgoldprods                    0.42                 0.44               0.38
# numdealspurchases               0.23                -0.01               0.07
# numwebpurchases                 1.00                 0.38               0.50
# numcatalogpurchases             0.38                 1.00               0.52
# numstorepurchases               0.50                 0.52               1.00
# numwebvisitsmonth              -0.06                -0.52              -0.43
# mnt_total_sin_vino              0.39                 0.75               0.56
#
#                      numwebvisitsmonth  mnt_total_sin_vino
# id                               -0.01               -0.01
# year_birth                        0.12               -0.04
# kidhome                           0.45               -0.50
# teenhome                          0.13               -0.25
# recency                          -0.02                0.02
# mntwines                         -0.32                0.59
# mntfruits                        -0.42                0.71
# mntmeatproducts                  -0.54                0.94
# mntfishproducts                  -0.45                0.75
# mntsweetproducts                 -0.42                0.69
# mntgoldprods                     -0.25                0.55
# numdealspurchases                 0.35               -0.13
# numwebpurchases                  -0.06                0.39
# numcatalogpurchases              -0.52                0.75
# numstorepurchases                -0.43                0.56
# numwebvisitsmonth                 1.00               -0.57
# mnt_total_sin_vino               -0.57                1.00

# %% [markdown]
# > Con los resultados del heatmap veremos más claras las conclusiones

# %% [markdown]
# 3. Con los resultados de la correlación del ejercicio anterior, cread un heatmap.

# %%
# Creamos una máscara
mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))
# Out:
# /var/folders/0b/r1tw2m0d04b5wkj6n99ypszr0000gn/T/ipykernel_2175/3959007233.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))

# %%
sns.heatmap(df.corr(),
            cmap = "YlGnBu", 
            mask = mask,
           annot = True)
plt.show();

# %% [markdown]
# > La correlación entre la cantidad total sin vino `mnt_total_sin_vino` y las cantidades gastadas en cada producto es muy alta porque la cantidad total es una suma de todas ellas. Vemos que hay mas correlación con `mntmeatproducts` y deducimos que es donde más dinero se gasta.
# > La siguiente correlación con más fuerza es la de la cantidad gastada en carne y ventas por catálogo, interpretamos que es la vía de compra más habitual (`mntmeatproducts` y `numcatalogpurchases`)
# > La relación entre las ventas de vino por catálogo y por tienda es la misma (`mntwines` , `numcatalogpurchases` y `numstorepurchases`)
# >

# %% [markdown]
# 4. Guardad la gráfica del heatmap.
